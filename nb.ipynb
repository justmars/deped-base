# %%
from environs import Env
from rich import print as rprint

env = Env()
src = env.path("ENROLL_DIR")
src.exists()
# Out:
# True

# %%
from foundation.extract_meta import META_COLS, process_enrollment_folder

# %%
df_long = process_enrollment_folder(src)
# Out:
# Combining all dataframes...
# Processing file: enrollment_2017-2018.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2018-2019.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2019-2020.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2020-2021.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2021-2022.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2022-2023.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2023-2024.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2024-2025.csv
# Melting wide enrollment columns → long...
# Processing file: enrollment_2025-2026.csv
# Melting wide enrollment columns → long...

# %%
df_long.columns
# Out:
# Index(['school_year', 'sector', 'school_management', 'school_id',
#        'school_name', 'region', 'province', 'municipality', 'barangay',
#        'street_address', 'legislative_district', 'division', 'school_district',
#        'annex_status', 'offers_es', 'offers_jhs', 'offers_shs', 'grade_sex',
#        'num_students', 'grade', 'strand', 'sex'],
#       dtype='object')

# %%
(
    df_long[df_long["school_management"] == "DepEd"]
    .groupby("school_year")["school_id"]
    .nunique()
    .reset_index(name="num_schools")
)
# Out:
#   school_year  num_schools
# 0   2017-2018        45666
# 1   2018-2019        45947
# 2   2019-2020        46981
# 3   2020-2021        47230
# 4   2021-2022        47364
# 5   2022-2023        47548
# 6   2023-2024        47798
# 7   2024-2025        47954
# 8   2025-2026        48115

# %%
rprint("[blue]Sorting consolidated enrollment data...[/blue]")
df_sorted = df_long.sort_values(["school_id", "school_year"], ascending=[True, False])

meta = df_sorted[["school_year"] + META_COLS].drop_duplicates(
    subset=["school_id", "school_year"], keep="first"
)
# Out:
# Sorting consolidated enrollment data...

# %%
len(meta)
# Out:
# 545681

# %%
(
    meta[meta["school_management"] == "DepEd"]
    .groupby("school_year")["school_id"]
    .nunique()
    .reset_index(name="num_schools")
)
# Out:
#   school_year  num_schools
# 0   2017-2018        45666
# 1   2018-2019        45947
# 2   2019-2020        46981
# 3   2020-2021        47230
# 4   2021-2022        47364
# 5   2022-2023        47548
# 6   2023-2024        47798
# 7   2024-2025        47954
# 8   2025-2026        48115
